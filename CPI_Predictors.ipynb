# %% [markdown]
# # CPI Predictors
# Which forward looking CPI estimates best predict actual CPI and Core CPI based on historical data since 1982? In this notebook I put the following ones to the test:
# * `STICKCPIM158SFRBATL` &mdash; Sticky Price Consumer Price Index (aka Sticky CPI). The Federal Reserve Bank of Atlanta calculates it from a subset of goods and services included in the CPI that change price relatively infrequently. Because these goods and services change price relatively infrequently, they are thought to incorporate expectations about future inflation to a greater degree than prices that change on a more frequent basis.
# * `EXPINF1YR` &mdash; An estimate of CPI over the next 12 months from the Federal Reserve bank of Cleveland. Its inflation expectation model uses the following inputs:
#   - Blue Chip forecast of CPI
#   - Inflation swap data
#   - CPI numbers for the current month
#   - CPI data from vintage FRED
#   - 1-month to 6-month treasury bill yield at constant maturity
#   - 1-year to 15-year US treasury yield: continuously compounded zero-coupon
#   - Survey of Professional Forecasters median year-over-year CPI inflation rate for the next 10 years
# * `MICH` &mdash; A survey-based estimate of CPI over the next 12 months from University of Michigan. Unfortunately FRED reports this University of Michigan estimate with a one month lag. To get the most recent estimate I retrieve it directly from [the surveys page](https://www.sca.isr.umich.edu/tables.html) of the  University of Michigan's website.
#
# I shift the respective Sticky CPI, Fed Reserve Bank of Cleveland 1-Year Expectated Inflation, and University of Michigan inflation expectation publications by 1 to 12 months forward and take [the root mean square error (RMSE)](https://en.wikipedia.org/wiki/Root-mean-square_deviation) between them and the actual CPI and core CPI in that month.

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import pandas_datareader.data as web
from datetime import date
from pandas.tseries.offsets import MonthBegin, DateOffset

# %%
report_start = date.fromisoformat('1959-01-01')
report_end = date.today()

# %%
cpis = web.get_data_fred(['CPIAUCSL', 'CPILFESL', 'STICKCPIM158SFRBATL', 'EXPINF1YR', 'MICH'], start=report_start, end=report_end)

# Getting the most recent month of the University of Michigan one year inflation expectations.
df = pd.read_csv('https://www.sca.isr.umich.edu/files/tbcpx1px5.csv', header=3, sep=',{2,10}', engine='python',
                 index_col='DATE OF SURVEY', skipfooter=1)
df = df.set_axis(pd.DatetimeIndex(df.index))
df.drop(df.columns[2], axis=1, inplace=True)
df.rename(columns={'NEXT YEAR': 'MICH'}, inplace=True)
cpis.update(df.loc[:,'MICH'])

cpis.iloc[:,2:] /= 100.

# Expected inflation from Reserve Bank of Cleveland and University of Michigan released on a given month indicated expected
# inflation in the same month of the following year.

cpis.update(cpis.iloc[:,:2].pct_change(12, fill_method=None))
cpis.dropna(subset=cpis.columns[3:], inplace=True)

# %%
cpis.rename(
    columns={'STICKCPIM158SFRBATL': 'Sticky CPI (Reserve Bank of Atlanta)',
             'EXPINF1YR': '1-Year Expected Inflation (Reserve Bank of Cleveland)',
             'MICH': '1-Year Expected Inflation (University of Michigan)'},
    inplace=True)

# %%
cpis
# Out:
#             CPIAUCSL  CPILFESL  Sticky CPI (Reserve Bank of Atlanta)  \
# DATE
# 1982-01-01  0.082569  0.092506                              0.045707
# 1982-02-01  0.076136  0.091967                              0.051338
# 1982-03-01  0.068849  0.086806                              0.002319
# 1982-04-01  0.066218  0.088506                              0.106899
# 1982-05-01  0.069119  0.086560                              0.132231
# ...              ...       ...                                   ...
# 2025-11-01  0.026964  0.025990                              0.013953
# 2025-12-01  0.026533  0.026465                              0.034457
# 2026-01-01  0.023912  0.025120                              0.043741
# 2026-02-01  0.024340  0.024725                              0.024984
# 2026-03-01       NaN       NaN                                   NaN
#
#             1-Year Expected Inflation (Reserve Bank of Cleveland)  \
# DATE
# 1982-01-01                                           0.063945
# 1982-02-01                                           0.064321
# 1982-03-01                                           0.063877
# 1982-04-01                                           0.061406
# 1982-05-01                                           0.054882
# ...                                                       ...
# 2025-11-01                                           0.027039
# 2025-12-01                                           0.031929
# 2026-01-01                                           0.025864
# 2026-02-01                                           0.025857
# 2026-03-01                                           0.022891
#
#             1-Year Expected Inflation (University of Michigan)
# DATE
# 1982-01-01                                              0.051
# 1982-02-01                                              0.052
# 1982-03-01                                              0.042
# 1982-04-01                                              0.047
# 1982-05-01                                              0.035
# ...                                                       ...
# 2025-11-01                                              0.045
# 2025-12-01                                              0.042
# 2026-01-01                                              0.040
# 2026-02-01                                              0.034
# 2026-03-01                                              0.038
#
# [531 rows x 5 columns]

# %%
def rmse(series_diff):
    return np.sqrt((series_diff**2).mean())

# %%
def construct_rmse_dataframe(date_from=None):
    """
    :param date_from: a datetime.date or pandas.Timestamp object indicating if
                      the calculation of RMSE should be limited to the range of months starting from the given date
    """
    rmse_cpi = []
    rmse_core_cpi = []
    rmse_cpi_exp = []
    rmse_core_cpi_exp = []
    rmse_cpi_mich = []
    rmse_core_cpi_mich = []

    _cpis = cpis if date_from is None else cpis.loc[date_from:]
                   
    idx = pd.Index(range(1, 13), name='Sticky CPI/Expected Inflation forward shift in months')
    for i in idx:
        cpis_shifted = pd.concat([_cpis.iloc[:,:2], _cpis.iloc[:,2:].shift(i)], axis=1)
        rmse_cpi.append(rmse(cpis_shifted.iloc[:,0]-cpis_shifted.iloc[:,2]))
        rmse_core_cpi.append(rmse(cpis_shifted.iloc[:,1]-cpis_shifted.iloc[:,2]))
        rmse_cpi_exp.append(rmse(cpis_shifted.iloc[:,0]-cpis_shifted.iloc[:,3]))
        rmse_core_cpi_exp.append(rmse(cpis_shifted.iloc[:,1]-cpis_shifted.iloc[:,3]))
        rmse_cpi_mich.append(rmse(cpis_shifted.iloc[:,0]-cpis_shifted.iloc[:,4]))
        rmse_core_cpi_mich.append(rmse(cpis_shifted.iloc[:,1]-cpis_shifted.iloc[:,4]))
    
    return pd.DataFrame(np.array([rmse_cpi, rmse_core_cpi, rmse_cpi_exp, rmse_core_cpi_exp, rmse_cpi_mich, rmse_core_cpi_mich]).T,
                index=idx, columns=['RMSE: CPI and Sticky CPI', 'RMSE: Core CPI and Sticky CPI',
                                    'RMSE: CPI and 1y Expected Infl', 'RMSE: Core CPI and 1y Expected Infl',
                                    'RMSE: CPI and Mich Infl Exp', 'RMSE: Core CPI and Mich Infl Exp'])

# %%
df_cpi_predictors = construct_rmse_dataframe()
date_for_last_10y = report_end - DateOffset(years=+10) - MonthBegin()
date_for_last_5y = report_end - DateOffset(years=+5) - MonthBegin()
df_cpi_predictors_last_10y = construct_rmse_dataframe(date_for_last_10y)
df_cpi_predictors_last_5y = construct_rmse_dataframe(date_for_last_5y)

# %%
df_cpi_predictors
# Out:
#                                                     RMSE: CPI and Sticky CPI  \
# Sticky CPI/Expected Inflation forward shift in ...
# 1                                                                   0.014882
# 2                                                                   0.015230
# 3                                                                   0.015732
# 4                                                                   0.016402
# 5                                                                   0.016935
# 6                                                                   0.017272
# 7                                                                   0.017679
# 8                                                                   0.017976
# 9                                                                   0.018314
# 10                                                                  0.018680
# 11                                                                  0.019190
# 12                                                                  0.020005
#
#                                                     RMSE: Core CPI and Sticky CPI  \
# Sticky CPI/Expected Inflation forward shift in ...
# 1                                                                        0.012028
# 2                                                                        0.012049
# 3                                                                        0.012267
# 4                                                                        0.012543
# 5                                                                        0.012649
# 6                                                                        0.012715
# 7                                                                        0.012949
# 8                                                                        0.012998
# 9                                                                        0.013102
# 10                                                                       0.013384
# 11                                                                       0.013858
# 12                                                                       0.014839
#
#                                                     RMSE: CPI and 1y Expected Infl  \
# Sticky CPI/Expected Inflation forward shift in ...
# 1                                                                         0.012880
# 2                                                                         0.013049
# 3                                                                         0.013283
# 4                                                                         0.013545
# 5                                                                         0.013833
# 6                                                                         0.014096
# 7                                                                         0.014358
# 8                                                                         0.014788
# 9                                                                         0.015339
# 10                                                                        0.015833
# 11                                                                        0.016328
# 12                                                                        0.016688
#
#                                                     RMSE: Core CPI and 1y Expected Infl  \
# Sticky CPI/Expected Inflation forward shift in ...
# 1                                                                              0.009057
# 2                                                                              0.008973
# 3                                                                              0.008955
# 4                                                                              0.008973
# 5                                                                              0.009039
# 6                                                                              0.009137
# 7                                                                              0.009288
# 8                                                                              0.009469
# 9                                                                              0.009718
# 10                                                                             0.009975
# 11                                                                             0.010276
# 12                                                                             0.010545
#
#                                                     RMSE: CPI and Mich Infl Exp  \
# Sticky CPI/Expected Inflation forward shift in ...
# 1                                                                      0.012578
# 2                                                                      0.012641
# 3                                                                      0.012751
# 4                                                                      0.012905
# 5                                                                      0.013088
# 6                                                                      0.013350
# 7                                                                      0.013738
# 8                                                                      0.014176
# 9                                                                      0.014597
# 10                                                                     0.014949
# 11                                                                     0.015365
# 12                                                                     0.015781
#
#                                                     RMSE: Core CPI and Mich Infl Exp
# Sticky CPI/Expected Inflation forward shift in ...
# 1                                                                           0.011755
# 2                                                                           0.011470
# 3                                                                           0.011248
# 4                                                                           0.011008
# 5                                                                           0.010773
# 6                                                                           0.010694
# 7                                                                           0.010768
# 8                                                                           0.010850
# 9                                                                           0.010956
# 10                                                                          0.010969
# 11                                                                          0.010948
# 12                                                                          0.011033

# %% [markdown]
# The purpose of the University of Michigan's inflation expectation indicator and the Federal Reserve Bank of Cleveland's 1-Year Expected Inflation measure is to predict the annual growth rate of the CPI in one year. In the graph below, they are intended to predict CPI inflation with a forward shift of 12 months. I have thickened the horizontal line to ensure it stands out in the graph.

# %%
ax = df_cpi_predictors.plot(
        figsize=(20,10), grid=True,
        title='Root Mean Square Error (RMSE) between actual CPI and Core CPI and CPI predicting metrics (from {:%Y-%m} till {:%Y-%m})'
            .format(cpis.index[0].date(), cpis.index[-1].date()),
        xticks=df_cpi_predictors.index, style=['-', '--']*3)
_ = ax.axvline(df_cpi_predictors.index[-1], color='k', lw=2)

# %% [markdown]
# ### Conclusion
# 1. The Federal Reserve Bank of Cleveland estimate of 1-Year Expected Inflation is head and shoulders the best predictor of actual Core CPI over the next 12 months. Despite its intent of predicting CPI over the next year, it is actually most effective at predicting Core CPI within 2 months.
# 2. The University of Michigan's Inflation Expectation for the next 12 months is the best predictor of overall CPI over the next year. Despite its aim to predict CPI over the next year, it is most accurate at forecasting CPI for the following three months.

# %% [markdown]
# ## Limiting the analysis to the last 10 and 5 years
# It's interesting to see if the conclusion would remain the same if we limit the calculation of RMSE to the last 10 and 5 years.

# %%
ax = df_cpi_predictors_last_10y.plot(
        figsize=(20,10), grid=True,
        title='Root Mean Square Error (RMSE) between actual CPI and Core CPI and CPI predicting metrics (from {:%Y-%m} till {:%Y-%m})'
            .format(date_for_last_10y, cpis.index[-1].date()),
        xticks=df_cpi_predictors_last_10y.index, style=['-', '--']*3)
_ = ax.axvline(df_cpi_predictors.index[-1], color='k', lw=2)

# %%
ax = df_cpi_predictors_last_5y.plot(
        figsize=(20,10), grid=True,
        title='Root Mean Square Error (RMSE) between actual CPI and Core CPI and CPI predicting metrics (from {:%Y-%m} till {:%Y-%m})'
            .format(date_for_last_5y, cpis.index[-1].date()),
        xticks=df_cpi_predictors_last_5y.index, style=['-', '--']*3)
_ = ax.axvline(df_cpi_predictors.index[-1], color='k', lw=2)

# %% [markdown]
# ### Conclusion 2
# When we limit the comparison to the past 10 and 5 years, the main differences are:
# 1. The University of Michigan's Inflation Expectation for the next 12 months is by far the best at predicting the Core CPI as well as overall CPI over the next 12 months (when we take the entire period from 1982, this indicator is the best only at predicting overall CPI inflation).
# 2. Sticky CPI does a better job at predicting both Core CPI and overall CPI over a 1-year time horizon than the Federal Reserve Bank of Cleveland's estimate of 1-Year Expected Inflation.

# %%
import seaborn as sns
cm = sns.color_palette('Blues', as_cmap=True)
IDX_FORMAT = '{:%Y-%m}'
pd.options.display.max_rows = 15

# %%
cpis.iloc[:,[3,4]].tail(18).style.format_index(IDX_FORMAT).format('{:.2%}')\
    .set_properties(subset=cpis.columns[[3,4]], **{'width': '200px'})\
    .set_table_styles([{'selector': 'th', 'props': 'text-align: right; width: 100px'}])\
    .background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_50979 th {
#   text-align: right;
#   width: 100px;
# }
# #T_50979_row0_col0 {
#   width: 200px;
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_50979_row0_col1 {
#   width: 200px;
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_50979_row1_col0 {
#   width: 200px;
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_50979_row1_col1, #T_50979_row5_col0 {
#   width: 200px;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_50979_row2_col0 {
#   width: 200px;
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_50979_row2_col1 {
#   width: 200px;
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_50979_row3_col0 {
#   width: 200px;
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_50979_row3_col1 {
#   width: 200px;
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_50979_row4_col0, #T_50979_row12_col0 {
#   width: 200px;
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_50979_row4_col1 {
#   width: 200px;
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_50979_row5_col1, #T_50979_row8_col1, #T_50979_row9_col0 {
#   width: 200px;
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_50979_row6_col0 {
#   width: 200px;
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_50979_row6_col1 {
#   width: 200px;
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_50979_row7_col0, #T_50979_row10_col0 {
#   width: 200px;
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_50979_row7_col1, #T_50979_row14_col0 {
#   width: 200px;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_50979_row8_col0 {
#   width: 200px;
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_50979_row9_col1, #T_50979_row13_col1 {
#   width: 200px;
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_50979_row10_col1 {
#   width: 200px;
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_50979_row11_col0 {
#   width: 200px;
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_50979_row11_col1 {
#   width: 200px;
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_50979_row12_col1 {
#   width: 200px;
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_50979_row13_col0 {
#   width: 200px;
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_50979_row14_col1, #T_50979_row15_col0 {
#   width: 200px;
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_50979_row15_col1 {
#   width: 200px;
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_50979_row16_col0 {
#   width: 200px;
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_50979_row16_col1 {
#   width: 200px;
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_50979_row17_col0 {
#   width: 200px;
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_50979_row17_col1 {
#   width: 200px;
#   background-color: #b7d4ea;
#   color: #000000;
# }
# </style>
# <table id="T_50979">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50979_level0_col0" class="col_heading level0 col0" >1-Year Expected Inflation (Reserve Bank of Cleveland)</th>
#       <th id="T_50979_level0_col1" class="col_heading level0 col1" >1-Year Expected Inflation (University of Michigan)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DATE</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50979_level0_row0" class="row_heading level0 row0" >2024-10</th>
#       <td id="T_50979_row0_col0" class="data row0 col0" >2.26%</td>
#       <td id="T_50979_row0_col1" class="data row0 col1" >2.70%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row1" class="row_heading level0 row1" >2024-11</th>
#       <td id="T_50979_row1_col0" class="data row1 col0" >2.43%</td>
#       <td id="T_50979_row1_col1" class="data row1 col1" >2.60%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row2" class="row_heading level0 row2" >2024-12</th>
#       <td id="T_50979_row2_col0" class="data row2 col0" >2.65%</td>
#       <td id="T_50979_row2_col1" class="data row2 col1" >2.80%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row3" class="row_heading level0 row3" >2025-01</th>
#       <td id="T_50979_row3_col0" class="data row3 col0" >2.63%</td>
#       <td id="T_50979_row3_col1" class="data row3 col1" >3.30%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row4" class="row_heading level0 row4" >2025-02</th>
#       <td id="T_50979_row4_col0" class="data row4 col0" >2.73%</td>
#       <td id="T_50979_row4_col1" class="data row4 col1" >4.30%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row5" class="row_heading level0 row5" >2025-03</th>
#       <td id="T_50979_row5_col0" class="data row5 col0" >2.18%</td>
#       <td id="T_50979_row5_col1" class="data row5 col1" >5.00%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row6" class="row_heading level0 row6" >2025-04</th>
#       <td id="T_50979_row6_col0" class="data row6 col0" >2.89%</td>
#       <td id="T_50979_row6_col1" class="data row6 col1" >6.50%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row7" class="row_heading level0 row7" >2025-05</th>
#       <td id="T_50979_row7_col0" class="data row7 col0" >2.69%</td>
#       <td id="T_50979_row7_col1" class="data row7 col1" >6.60%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row8" class="row_heading level0 row8" >2025-06</th>
#       <td id="T_50979_row8_col0" class="data row8 col0" >2.38%</td>
#       <td id="T_50979_row8_col1" class="data row8 col1" >5.00%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row9" class="row_heading level0 row9" >2025-07</th>
#       <td id="T_50979_row9_col0" class="data row9 col0" >2.79%</td>
#       <td id="T_50979_row9_col1" class="data row9 col1" >4.50%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row10" class="row_heading level0 row10" >2025-08</th>
#       <td id="T_50979_row10_col0" class="data row10 col0" >2.69%</td>
#       <td id="T_50979_row10_col1" class="data row10 col1" >4.80%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row11" class="row_heading level0 row11" >2025-09</th>
#       <td id="T_50979_row11_col0" class="data row11 col0" >2.80%</td>
#       <td id="T_50979_row11_col1" class="data row11 col1" >4.70%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row12" class="row_heading level0 row12" >2025-10</th>
#       <td id="T_50979_row12_col0" class="data row12 col0" >2.73%</td>
#       <td id="T_50979_row12_col1" class="data row12 col1" >4.60%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row13" class="row_heading level0 row13" >2025-11</th>
#       <td id="T_50979_row13_col0" class="data row13 col0" >2.70%</td>
#       <td id="T_50979_row13_col1" class="data row13 col1" >4.50%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row14" class="row_heading level0 row14" >2025-12</th>
#       <td id="T_50979_row14_col0" class="data row14 col0" >3.19%</td>
#       <td id="T_50979_row14_col1" class="data row14 col1" >4.20%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row15" class="row_heading level0 row15" >2026-01</th>
#       <td id="T_50979_row15_col0" class="data row15 col0" >2.59%</td>
#       <td id="T_50979_row15_col1" class="data row15 col1" >4.00%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row16" class="row_heading level0 row16" >2026-02</th>
#       <td id="T_50979_row16_col0" class="data row16 col0" >2.59%</td>
#       <td id="T_50979_row16_col1" class="data row16 col1" >3.40%</td>
#     </tr>
#     <tr>
#       <th id="T_50979_level0_row17" class="row_heading level0 row17" >2026-03</th>
#       <td id="T_50979_row17_col0" class="data row17 col0" >2.29%</td>
#       <td id="T_50979_row17_col1" class="data row17 col1" >3.80%</td>
#     </tr>
#   </tbody>
# </table>
